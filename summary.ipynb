# %%
import json
import os
from openai import OpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.chat_models import ChatOpenAI
from langchain.schema import HumanMessage
import chromadb
from chromadb.config import Settings
import requests

from langchain_openai import OpenAIEmbeddings
import chromadb
from chromadb.config import Settings

import numpy as np

# %%
# Set up API key and embedding model
openai_api_key = os.getenv("OPENAI_API_KEY")
openai_client = OpenAI(api_key=openai_api_key)
embeddings = OpenAIEmbeddings(openai_api_key=openai_api_key)
embedding_model =OpenAIEmbeddings(openai_api_key=openai_api_key)
file_path = "Push_Commit_summary_outout.txt"

# %%
def create_summary_of_events():
    # with open("push_events.json", "r") as file:
    #     data = json.load(file)
    # owner = data[2]
    # repo_name = data[3]
    api_url = f"https://api.github.com/repos/arunkenwal02/code-validator/events"
    response = requests.get(api_url)
    events = response.json()
    push_ids = [id['id'] for id in events]
    # print(push_ids)
    data = ['52949273211','52821120274']
    push_events = [e for e in events if e['type'] == 'PushEvent']

    ids = [e['id'] for e in push_events]
    try:
        idx1 = ids.index(data[0])
        idx2 = ids.index(data[1])
    except ValueError:
        return {"error": "One or both push IDs not found in recent events."}

    start = min(idx1, idx2)
    end = max(idx1, idx2)

    history_between = push_events[start:end+1]  
    grouped_push_events = []
    commits_list = []
    for event in history_between:
        push_id = event['id']
        created_at = event['created_at']
        repo = event['repo']['name']
        commits_list = []

        for commit in event["payload"]["commits"]:
            sha = commit['sha']
            author = commit['author']['name']
            message = commit['message']

            commit_detail_url = f"https://api.github.com/repos/arunkenwal02/code-validator/commits/{sha}"
            commit_detail_response = requests.get(commit_detail_url)

            if commit_detail_response.status_code != 200:
                diff = "❌ Failed to fetch diff"
            else:
                commit_detail = commit_detail_response.json()
                diffs = []
                for file in commit_detail.get('files', []):
                    patch = file.get('patch')
                    if patch:
                        diffs.append(f"File: {file['filename']}\n{patch}")
                diff = "\n\n".join(diffs) if diffs else "No diff available"

            commits_list.append({
                "sha": sha,
                "author": author,
                "commit_message": message,
                "code_diff": diff
            })

        grouped_push_events.append({
            "push_id": push_id,
            "repo": repo,
            "created_at": created_at,
            "commits": commits_list
        })
    return grouped_push_events

# %%
grouped_push_events = create_summary_of_events()
grouped_push_events
# Out:
# [{'push_id': '52949273211',
#   'repo': 'arunkenwal02/code-validator',
#   'created_at': '2025-08-05T05:36:54Z',
#   'commits': [{'sha': 'c536e703bf0e78761d6374044ef7d9c2bb482131',
#     'author': 'Vipin',
#     'commit_message': 'Updated requirements.txt',
#     'code_diff': 'File: requirements.txt\n@@ -1,119 +1,234 @@\n+GitPython==3.1.45\n+Jinja2==3.1.6\n+Markdown==3.8.2\n+MarkupSafe==3.0.2\n+PyMuPDF==1.26.3\n+PyPika==0.48.9\n+PyYAML==6.0.2\n+RapidFuzz==3.13.0\n+SQLAlchemy==2.0.40\n+acres==0.5.0\n+aiofiles==24.1.0\n+aiohappyeyeballs==2.6.1\n+aiohttp==3.11.18\n+aiosignal==1.3.2\n altair==5.5.0\n+annotated-types==0.7.0\n anyio==4.9.0\n-appnope==0.1.4\n-argon2-cffi==25.1.0\n-argon2-cffi-bindings==21.2.0\n-arrow==1.3.0\n-asttokens==3.0.0\n-async-lru==2.0.5\n attrs==25.3.0\n-babel==2.17.0\n+backoff==2.2.1\n+bcrypt==4.3.0\n beautifulsoup4==4.13.4\n-bleach==6.2.0\n blinker==1.9.0\n-cachetools==6.1.0\n-certifi==2025.7.14\n+build==1.2.2.post1\n+cachetools==5.5.2\n+certifi==2025.4.26\n cffi==1.17.1\n+cfgv==3.4.0\n charset-normalizer==3.4.2\n+chromadb==1.0.15\n+ci-info==0.3.0\n click==8.2.1\n-comm==0.2.3\n-debugpy==1.8.15\n-decorator==5.2.1\n-defusedxml==0.7.1\n-executing==2.2.0\n+coloredlogs==15.0.1\n+configobj==5.0.9\n+configparser==7.2.0\n+contourpy==1.3.3\n+cryptography==45.0.5\n+cycler==0.12.1\n+dataclasses-json==0.6.7\n+diagrams==0.24.4\n+distlib==0.4.0\n+distro==1.9.0\n+docstring_parser==0.16\n+dotenv==0.9.9\n+durationpy==0.10\n+emoji==2.14.1\n+etelemetry==0.3.1\n+faiss-cpu==1.11.0.post1\n+fastapi==0.116.1\n+fastavro==1.11.1\n fastjsonschema==2.21.1\n-fqdn==1.5.1\n+filelock==3.18.0\n+filetype==1.2.0\n+flatbuffers==25.2.10\n+fonttools==4.59.0\n+frontend==0.0.3\n+frozenlist==1.6.0\n+fsspec==2025.5.1\n gitdb==4.0.12\n-GitPython==3.1.45\n+graphviz==0.20.3\n+greenlet==3.2.1\n h11==0.16.0\n+html5lib==1.1\n httpcore==1.0.9\n+httplib2==0.22.0\n+httptools==0.6.4\n+httpx-sse==0.4.0\n httpx==0.28.1\n+huggingface-hub==0.33.2\n+humanfriendly==10.0\n+identify==2.6.12\n idna==3.10\n-ipykernel==6.30.0\n-ipython==9.4.0\n-ipython_pygments_lexers==1.1.1\n-ipywidgets==8.1.7\n-isoduration==20.11.0\n-jedi==0.19.2\n-Jinja2==3.1.6\n-json5==0.12.0\n+importlib_resources==6.5.2\n+isodate==0.7.2\n+itsdangerous==2.2.0\n+jiter==0.9.0\n+joblib==1.5.1\n+jpype1==1.6.0\n+jsonpatch==1.33\n jsonpointer==3.0.0\n-jsonschema==4.25.0\n jsonschema-specifications==2025.4.1\n-jupyter==1.1.1\n-jupyter-console==6.6.3\n-jupyter-events==0.12.0\n-jupyter-lsp==2.2.6\n-jupyter_client==8.6.3\n-jupyter_core==5.8.1\n-jupyter_server==2.16.0\n-jupyter_server_terminals==0.5.3\n-jupyterlab==4.4.5\n-jupyterlab_pygments==0.3.0\n-jupyterlab_server==2.27.3\n-jupyterlab_widgets==3.0.15\n-lark==1.2.2\n-MarkupSafe==3.0.2\n-matplotlib-inline==0.1.7\n-mistune==3.1.3\n+jsonschema==4.25.0\n+kiwisolver==1.4.8\n+langchain-cohere==0.4.4\n+langchain-community==0.3.27\n+langchain-core==0.3.72\n+langchain-experimental==0.3.4\n+langchain-groq==0.3.6\n+langchain-openai==0.3.28\n+langchain-tavily==0.1.6\n+langchain-text-splitters==0.3.9\n+langchain-xai==0.2.5\n+langchain==0.3.27\n+langdetect==1.0.9\n+langgraph-checkpoint==2.0.25\n+langgraph-prebuilt==0.1.8\n+langgraph-sdk==0.1.66\n+langgraph==0.4.3\n+langsmith==0.3.45\n+looseversion==1.3.0\n+lxml==6.0.0\n+markdown-it-py==3.0.0\n+marshmallow==3.26.1\n+matplotlib==3.10.3\n+mdurl==0.1.2\n+mizani==0.14.2\n+mmh3==5.1.0\n+mpmath==1.3.0\n+msrest==0.7.1\n+multidict==6.4.3\n+mypy==1.15.0\n+mypy_extensions==1.1.0\n narwhals==1.48.1\n-nbclient==0.10.2\n-nbconvert==7.16.6\n nbformat==5.10.4\n-nest-asyncio==1.6.0\n-notebook==7.4.4\n-notebook_shim==0.2.4\n-numpy==2.3.2\n+nest_asyncio\n+nibabel==5.3.2\n+nipype==1.10.0\n+nltk==3.9.1\n+nodeenv==1.9.1\n+numpy==2.2.5\n+oauthlib==3.2.2\n+olefile==0.47\n+onnxruntime==1.22.1\n+openai==1.98.0\n+opentelemetry-api==1.35.0\n+opentelemetry-exporter-otlp-proto-common==1.35.0\n+opentelemetry-exporter-otlp-proto-grpc==1.35.0\n+opentelemetry-proto==1.35.0\n+opentelemetry-sdk==1.35.0\n+opentelemetry-semantic-conventions==0.56b0\n+orjson==3.10.18\n+ormsgpack==1.9.1\n overrides==7.7.0\n-packaging==25.0\n-pandas==2.3.1\n-pandocfilters==1.5.1\n-parso==0.8.4\n-pexpect==4.9.0\n+packaging==24.2\n+pandas==2.2.3\n+pathlib==1.0.1\n+patsy==1.0.1\n+pdfminer.six==20250506\n+pdfplumber==0.11.7\n pillow== ...
#  {'push_id': '52949184387',
#   'repo': 'arunkenwal02/code-validator',
#   'created_at': '2025-08-05T05:33:50Z',
#   'commits': [{'sha': '5ef4b5b48eca8cad8d86e8d88904fcb2384e8dbb',
#     'author': 'Vipin',
#     'commit_message': 'updated white paper',
#     'code_diff': 'No diff available'}]},
#  {'push_id': '52947410795',
#   'repo': 'arunkenwal02/code-validator',
#   'created_at': '2025-08-05T04:26:18Z',
#   'commits': [{'sha': '8ad9ffaa235a48de153eab057f7b819b7c1bd7a9',
#     'author': 'Vipin',
#     'commit_message': 'deleted loan approval prediction, white paper pdf and text file\n\nWhite paper and loan prediction white paper both are same, removed duplicate files.\nremoved loan approval prediction.ipynb',
#     'code_diff': 'File: white paper.txt\n@@ -1,20 +0,0 @@\n-Following are the features needs to be implement as classification :\r\n-\r\n-Featres:\r\n-    - sepal width (cm)\r\n-    - petal length (cm)\r\n-    - petal width (cm)\r\n-\r\n-Models Name:\r\n-    - Logistic Regression\r\n-\r\n-Hyperparameters:\r\n-\r\n-\r\n-Validation Matrics:  \r\n-    - Accuracy :90%\r\n-    - Precision : 90%\r\n-    - Recall : 85%\r\n-    - F1 : 88%\r\n-\r\n-\r'},
#    {'sha': '3235599a14b30870d1d26b5b3f3cb45796a4ba78',
#     'author': 'Vipin',
#     'commit_message': 'Added Loan prediction white paper pdf and docs and loan approval prediction v1 and v2\n\nLoan approval v1 is old version and v2 is new version. white paper is updated as per old version',
#     'code_diff': 'No diff available'}]},
#  {'push_id': '52905126625',
#   'repo': 'arunkenwal02/code-validator',
#   'created_at': '2025-08-04T08:46:35Z',
#   'commits': [{'sha': '9e8f1e36c0bdcc45ec0cb24122bfab05514e926b',
#     'author': 'Arun Kenwal',
#     'commit_message': 'hello comment added',
#     'code_diff': 'File: main.py\n@@ -15,6 +15,7 @@\n \r\n client = chromadb.Client(Settings())\r\n # check commits\r\n+# hello \r\n load_dotenv()\r\n import streamlit as st\r\n import fitz\r'}]},
#  {'push_id': '52904484290',
#   'repo': 'arunkenwal02/code-validator',
#   'created_at': '2025-08-04T08:32:04Z',
#   'commits': [{'sha': 'b8966abb082c689e1cbd27ff4f33cede1e8e945f',
#     'author': 'arunkenwal02',
#     'commit_message': 'checking coe push using token',
#     'code_diff': 'File: main.py\n@@ -14,7 +14,7 @@\n import tempfile\r\n \r\n client = chromadb.Client(Settings())\r\n-\r\n+# check commits\r\n load_dotenv()\r\n import streamlit as st\r\n import fitz\r'}]},
#  {'push_id': '52901658358',
#   'repo': 'arunkenwal02/code-validator',
#   'created_at': '2025-08-04T07:25:51Z',
#   'commits': [{'sha': '099c9ac21a023cc31580a485eb395dc88ab239dc',
#     'author': 'Vipin',
#     'commit_message': 'Updated White paper and main.py\n\nUpdated white paper - replace 5 pages white paper with 13pages\nmain.py- implemented features to extract white paper from pdf.\n\nuse multiple queries to compare white paper with model.\nextract most similar chunks from white paper and refine with llm and same for model output.\n\ncompare refine model and white paper output.\nand create summary',
#     'code_diff': 'File: main.ipynb\n@@ -2,7 +2,7 @@\n  "cells": [\n   {\n    "cell_type": "code",\n-   "execution_count": 1,\n+   "execution_count": null,\n    "id": "d5e18532",\n    "metadata": {},\n    "outputs": [],\n@@ -16,7 +16,7 @@\n     "import os\\n",\n     "import nbformat\\n",\n     "import streamlit as st\\n",\n-    "import tempfile\\n"\n+    "import tempfile"\n    ]\n   },\n   {\n@@ -27,8 +27,8 @@\n    "outputs": [],\n    "source": [\n     "\'\'\'\\n",\n-    "1. Load White Paper  (PDF)\\n",\n-    "2. Vectors Embeddings\\n",\n+    "1. Load White Paper  (PDF)  \\n",\n+    "2. Vectors Embeddings - Text and tables; later include images\\n",\n     "3. Chroma db\\n",\n     "4. Retrival - (Accuracy)\\n",\n     "5. Generation - \\n",\n@@ -39,10 +39,15 @@\n     "        Model Details \\n",\n     "        Hyperparameter\\n",\n     "        List of Validation Metrics and resepctive scores\\n",\n-    "        Compare Validation scores of white paper with code output and \\n",\n-    "\\n",\n+    "        Compare Validation scores of white paper with model\'s validation scores\\n",\n+    "        Brief of comparision of scores\\n",\n     "\\n",\n+    "        List and Track of critical metrics - these should not be lower than mentioned (in white paper)\\n",\n     "\\n",\n+    "6. Respective scores for tracked metrics (confidence on generation)\\n",\n+    "7. If required update prompt and go back to step 4 and reiterate step 4 and 5. reason (geneation have \\n",\n+    "   heiger confidence )\\n",\n+    "8. Outout should be in structured format (This will be input for summary block with affitional 2 inputs)\\n",\n     "\'\'\'"\n    ]\n   },\n\nFile: main.py\n@@ -1,21 +1,31 @@\n+import os\r\n+import nbformat\r\n+from openai import OpenAI\r\n from langchain.chat_models import ChatOpenAI\r\n from langchain.schema import SystemMessage, HumanMessage\r\n-from langchain.prompts import ChatPromptTemplate\r\n-from IPython.display import Markdown, display\r\n+from langchain.chat_models import ChatOpenAI\r\n+from langchain.schema import SystemMessage, HumanMessage\r\n+from langchain_openai import OpenAIEmbeddings\r\n from dotenv import load_dotenv\r\n-load_dotenv()\r\n-import os\r\n-import nbformat\r\n-import streamlit as st\r\n+from langchain.text_splitter import RecursiveCharacterTextSplitter\r\n+import chromadb\r\n+from chromadb.config import Settings\r\n+\r\n import tempfile\r\n \r\n+client = chromadb.Client(Settings())\r\n+\r\n+load_dotenv()\r\n+import streamlit as st\r\n+import fitz\r\n openai_api_key = os.getenv("OPENAI_API_KEY")\r\n \r\n # Initialize LLM\r\n llm = ChatOpenAI(model="gpt-4o",  \r\n                  temperature=0,\r\n                  openai_api_key= openai_api_key)\r\n \r\n+embedding_model = OpenAIEmbeddings(model="text-embedding-3-small") \r\n \r\n \r\n \r\n@@ -78,6 +88,33 @@ def extract_functionalities_from_whitepaper(whitepaper_text):\n     return llm(prompt).content.strip()\r\n \r\n \r\n+def refine_extracted_elements_with_context(similar_elements, query_context):\r\n+    """Uses LLM to refine extracted elements based on query context."""\r\n+    combined_elements = "\\n\\n".join(similar_elements)\r\n+    prompt = [\r\n+        SystemMessage(content="You are a product analyst."),\r\n+        HumanMessage(content=f"""\r\n+        The following are the top 5 similar elements retrieved from a vector database:\r\n+\r\n+        {combined_elements}\r\n+\r\n+        The original query context is:\r\n+        "{query_context}"\r\n+\r\n+        \r\n+        - **Objective**: Refine query context and extract only the most relevant functionalities and insights.\r\n+        - **Instructions**:\r\n+        - Analyze the query context to determine the user\'s intent.\r\n+        - Identify and extract only the most relevant elements or functionalities.\r\n+        - Provide concise, bullet-pointed outputs or insights based on retrieved data.\r\n+        - Avoid verbose explanations; focus on clarity and precision.\r\n+        - Fo ...
#  {'push_id': '52821120274',
#   'repo': 'arunkenwal02/code-validator',
#   'created_at': '2025-08-01T07:33:25Z',
#   'commits': [{'sha': '54097c86dc3bfadebb3ab591cd2cce4437e73dd1',
#     'author': 'Vipin',
#     'commit_message': 'added structure to retrieve from pdf',
#     'code_diff': 'File: main.ipynb\n@@ -0,0 +1,272 @@\n+{\n+ "cells": [\n+  {\n+   "cell_type": "code",\n+   "execution_count": 1,\n+   "id": "d5e18532",\n+   "metadata": {},\n+   "outputs": [],\n+   "source": [\n+    "from langchain.chat_models import ChatOpenAI\\n",\n+    "from langchain.schema import SystemMessage, HumanMessage\\n",\n+    "from langchain.prompts import ChatPromptTemplate\\n",\n+    "from IPython.display import Markdown, display\\n",\n+    "from dotenv import load_dotenv\\n",\n+    "load_dotenv()\\n",\n+    "import os\\n",\n+    "import nbformat\\n",\n+    "import streamlit as st\\n",\n+    "import tempfile\\n"\n+   ]\n+  },\n+  {\n+   "cell_type": "code",\n+   "execution_count": null,\n+   "id": "913e4307",\n+   "metadata": {},\n+   "outputs": [],\n+   "source": [\n+    "\'\'\'\\n",\n+    "1. Load White Paper  (PDF)\\n",\n+    "2. Vectors Embeddings\\n",\n+    "3. Chroma db\\n",\n+    "4. Retrival - (Accuracy)\\n",\n+    "5. Generation - \\n",\n+    "    Validation-\\n",\n+    "        Data sources - List all sources and metadata\\n",\n+    "        Features - detect any change in features\\n",\n+    "        Changes in Transformation steps\\n",\n+    "        Model Details \\n",\n+    "        Hyperparameter\\n",\n+    "        List of Validation Metrics and resepctive scores\\n",\n+    "        Compare Validation scores of white paper with code output and \\n",\n+    "\\n",\n+    "\\n",\n+    "\\n",\n+    "\'\'\'"\n+   ]\n+  },\n+  {\n+   "cell_type": "code",\n+   "execution_count": 2,\n+   "id": "e1358c3d",\n+   "metadata": {},\n+   "outputs": [\n+    {\n+     "name": "stderr",\n+     "output_type": "stream",\n+     "text": [\n+      "C:\\\\Users\\\\kumar\\\\AppData\\\\Local\\\\Temp\\\\ipykernel_26552\\\\3010324141.py:4: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.\\n",\n+      "  llm = ChatOpenAI(model=\\"gpt-4o\\",\\n"\n+     ]\n+    }\n+   ],\n+   "source": [\n+    "openai_api_key = os.getenv(\\"OPENAI_API_KEY\\")\\n",\n+    "\\n",\n+    "# Initialize LLM\\n",\n+    "llm = ChatOpenAI(model=\\"gpt-4o\\",  \\n",\n+    "                 temperature=0,\\n",\n+    "                 openai_api_key= openai_api_key)\\n",\n+    "\\n",\n+    "\\n"\n+   ]\n+  },\n+  {\n+   "cell_type": "code",\n+   "execution_count": 3,\n+   "id": "15f30bad",\n+   "metadata": {},\n+   "outputs": [],\n+   "source": [\n+    "\\n",\n+    "\\n",\n+    "def read_notebook(file_path):\\n",\n+    "    \\"\\"\\"Read .ipynb notebook and extract content.\\"\\"\\"\\n",\n+    "    nb = nbformat.read(file_path, as_version=4)\\n",\n+    "    content = []\\n",\n+    "    for cell in nb.cells:\\n",\n+    "        if cell.cell_type == \'markdown\':\\n",\n+    "            content.append(\\"## Markdown Cell:\\\\n\\" + cell.source)\\n",\n+    "        elif cell.cell_type == \'code\':\\n",\n+    "            content.append(\\"## Code Cell:\\\\n```python\\\\n\\" + cell.source + \\"\\\\n```\\")\\n",\n+    "    return \\"\\\\n\\\\n\\".join(content)\\n",\n+    "\\n",\n+    "\\n",\n+    "def read_file(file_path):\\n",\n+    "    \\"\\"\\"Reads the content of a file.\\"\\"\\"\\n",\n+    "    with open(file_path, \\"r\\", encoding=\\"utf-8\\") as f:\\n",\n+    "        return f.read()\\n",\n+    "\\n",\n+    "\\n",\n+    "def extract_functionalities_from_code(notebook_content):\\n",\n+    "\\n",\n+    "    \\"\\"\\"Uses LLM to extract functionalities from Python code.\\"\\"\\"\\n",\n+    "    prompt = f\\"\\"\\"\\n",\n+    "    You are an expert Python code reviewer. Here is a Jupyter notebook:\\n",\n+    "    {notebook_content}\\n",\n+    "\\n",\n+    "    The following is a Jupyter notebook content (code and markdown). \\n",\n+    "    Please extract the fol ...

# %%
def extract_commit_info(json_str, tag_id):
    push_info =json_str
    commit_structured = []
    for commit in push_info['commits']:
        # Simple file name extraction for single-file diffs
        file_line = commit['code_diff'].split('\n')[0]
        file_name = file_line.replace('File: ', '').strip()
        commit_structured.append({
            "push_id": push_info["push_id"],
            "repo": push_info["repo"],
            "created_at": push_info["created_at"],
            "commit_sha": commit["sha"],
            "author": commit["author"],
            "commit_message": commit["commit_message"],
            "file_name": file_name,
            "code_diff": commit["code_diff"],
            "tag_id": tag_id
        })
    return commit_structured

all_records = []
for js in grouped_push_events:
    records = extract_commit_info(js, tag_id="push_metadata")
    all_records.extend(records)

# %%
# all_records[0]

# %%
# Set up ChromaDB client and collection
# chroma_client = chromadb.Client(Settings(persist_directory="./chroma_openai1"))
# collection = chroma_client.get_or_create_collection(name="git_diff_chunks")


chroma_client = chromadb.PersistentClient(path="./chroma_storage")
collection = chroma_client.get_or_create_collection(name="git_diff_chunks")

# %%
collections = chroma_client.list_collections()
for c in collections:
    print(c.name)

# chroma_client.delete_collection(name="git_diff_chunks")

# collection = chroma_client.get_or_create_collection(name="git_diff_chunks")
# Out:
# git_diff_chunks

# %%
def store_push_and_commit_into_chroma_db(all_records,collection, embedding_model):

    documents = [rec["code_diff"] for rec in all_records]
    metadatas = [
        {
            "push_id": rec["push_id"],
            "repo": rec["repo"],
            "created_at": rec["created_at"],
            "commit_sha": rec["commit_sha"],
            "author": rec["author"],
            "commit_message": rec["commit_message"],
            "file_name": rec["file_name"],
            "tag_id": rec["tag_id"]
        }
        for rec in all_records
    ]
    ids = [f'{rec["push_id"]}_{rec["commit_sha"]}' for rec in all_records]

    dummy_vec = np.random.rand(1536).tolist()  # This creates a random 1536-d vector

    # collection.add(
    #     documents=["dummy doc"],            # or your real text
    #     embeddings=[dummy_vec],             # your real 1536-d vector
    #     ids=["dummy_id"]
    # )

    for rec in all_records:
    
        code_diff_embedding = embedding_model.embed_query(rec["code_diff"])
        commit_msg_embedding = embedding_model.embed_query(rec["commit_message"])

        # Prepare metadata (excluding the actual text fields)
        metadata = {k: v for k, v in rec.items() if k not in ["code_diff", "commit_message"]}

        # Store code_diff embedding
        
        print(code_diff_embedding)
        collection.add(
            documents=[rec["code_diff"]],
            embeddings=[code_diff_embedding],
            ids=[f'{rec["push_id"]}_{rec["commit_sha"]}_code'],
            metadatas=[{**metadata, "embedding_type": "code_diff"}]
        )

        # Store commit_message embedding
        print("---------------------------------------------------------------")
        print(commit_msg_embedding)
        collection.add(
            documents=[rec["commit_message"]],
            embeddings=[code_diff_embedding],
            ids=[f'{rec["push_id"]}_{rec["commit_sha"]}_msg'],
            metadatas=[{**metadata, "embedding_type": "commit_message"}]
        )

    
    # chroma_client.persist() 

    return collection

# %%
collection = store_push_and_commit_into_chroma_db(all_records = all_records,collection = collection, embedding_model = embedding_model)
# Out:
# [0.009179099462926388, 0.00037041306495666504, 0.009941188618540764, -0.012295502237975597, -0.01581336371600628, 0.012955525889992714, -0.013622354716062546, -0.002585661830380559, -0.01593584194779396, -0.028496714308857918, 0.03753292188048363, -0.01743280328810215, -0.003286512102931738, 0.008682379499077797, 0.0019851757679134607, 0.0006255770567804575, 0.01130206324160099, -0.0029922230169177055, 0.018671199679374695, -0.007831833325326443, 0.032878730446100235, -0.01231591496616602, -0.03432125598192215, -0.030592460185289383, -0.014112269505858421, 0.02065807580947876, 0.005389063619077206, -0.028877759352326393, -0.001297934097237885, -0.005889184772968292, 0.047195132821798325, -0.016384929418563843, -0.025897443294525146, -0.013676789589226246, -0.008627944625914097, -0.001388942589983344, 0.003973753657191992, -0.012452002
733, -0.0047271475195884705, -0.008748316206037998, 0.001643948256969452, -0.00591348297894001, 0.007576536387205124, 4.4095249904785305e-05, 0.010858974419534206, 0.0005717883468605578, -0.025386128574609756, 0.04002973064780235, -0.009832757525146008, 0.012991467490792274, -0.04294098541140556, -0.029738450422883034, 0.017016274854540825, 0.02064078487455845, -0.005567771848291159, -0.009141335263848305, -0.00038255687104538083, 0.0186611320823431, 0.04428016021847725, -0.00463980995118618, 0.008435356430709362, -0.011892469599843025, -0.00532759353518486, -0.0006927872891537845, -0.01826811395585537, -0.004101227968931198, -0.01550242304801941, -0.002738397568464279, -0.026943648234009743, 0.012270932085812092, 0.006019015796482563, -0.006281028501689434, 0.007765767630189657, 0.011281105689704418, 0.008398965001106262, -0.030480820685625076, 0.03379964828491211, 0.03708936646580696, 0.0012391021009534597, -0.02375582605600357, 0.024803876876831055, -0.01155767496675253, 0.0070634279400110245, 0.014345199801027775, -0.003193280892446637, -0.007412778213620186, -0.0002286925882799551, 0.016288461163640022, 0.013777505606412888, 0.03097573295235634, -0.008864765986800194,  ...

# %%
# # Generate asd store embeddings
# for rec in all_records:
    
#     code_diff_embedding = embedding_model.embed_query(rec["code_diff"])
#     commit_msg_embedding = embedding_model.embed_query(rec["commit_message"])

#     # Prepare metadata (excluding the actual text fields)
#     metadata = {k: v for k, v in rec.items() if k not in ["code_diff", "commit_message"]}

#     # Store code_diff embedding
    
#     print(code_diff_embedding)
#     collection.add(
#         documents=[rec["code_diff"]],
#         embeddings=[code_diff_embedding],
#         ids=[f'{rec["push_id"]}_{rec["commit_sha"]}_code'],
#         metadatas=[{**metadata, "embedding_type": "code_diff"}]
#     )

#     # Store commit_message embedding
#     print("---------------------------------------------------------------")
#     print(commit_msg_embedding)
#     collection.add(
#         documents=[rec["commit_message"]],
#         embeddings=[commit_msg_embedding],
#         ids=[f'{rec["push_id"]}_{rec["commit_sha"]}_msg'],
#         metadatas=[{**metadata, "embedding_type": "commit_message"}]
#     )

# %%
data = collection.get()

# %%
data['metadatas']
# Out:
# [{'push_id': '52949273211',
#   'author': 'Vipin',
#   'tag_id': 'push_metadata',
#   'file_name': 'requirements.txt',
#   'repo': 'arunkenwal02/code-validator',
#   'commit_sha': 'c536e703bf0e78761d6374044ef7d9c2bb482131',
#   'created_at': '2025-08-05T05:36:54Z',
#   'embedding_type': 'code_diff'},
#  {'tag_id': 'push_metadata',
#   'file_name': 'requirements.txt',
#   'commit_sha': 'c536e703bf0e78761d6374044ef7d9c2bb482131',
#   'author': 'Vipin',
#   'embedding_type': 'commit_message',
#   'push_id': '52949273211',
#   'created_at': '2025-08-05T05:36:54Z',
#   'repo': 'arunkenwal02/code-validator'},
#  {'embedding_type': 'code_diff',
#   'tag_id': 'push_metadata',
#   'repo': 'arunkenwal02/code-validator',
#   'author': 'Vipin',
#   'push_id': '52949184387',
#   'created_at': '2025-08-05T05:33:50Z',
#   'file_name': 'No diff available',
#   'commit_sha': '5ef4b5b48eca8cad8d86e8d88904fcb2384e8dbb'},
#  {'push_id': '52949184387',
#   'created_at': '2025-08-05T05:33:50Z',
#   'embedding_type': 'commit_message',
#   'repo': 'arunkenwal02/code-validator',
#   'author': 'Vipin',
#   'file_name': 'No diff available',
#   'tag_id': 'push_metadata',
#   'commit_sha': '5ef4b5b48eca8cad8d86e8d88904fcb2384e8dbb'},
#  {'repo': 'arunkenwal02/code-validator',
#   'push_id': '52947410795',
#   'created_at': '2025-08-05T04:26:18Z',
#   'tag_id': 'push_metadata',
#   'commit_sha': '8ad9ffaa235a48de153eab057f7b819b7c1bd7a9',
#   'embedding_type': 'code_diff',
#   'author': 'Vipin',
#   'file_name': 'white paper.txt'},
#  {'tag_id': 'push_metadata',
#   'file_name': 'white paper.txt',
#   'push_id': '52947410795',
#   'created_at': '2025-08-05T04:26:18Z',
#   'commit_sha': '8ad9ffaa235a48de153eab057f7b819b7c1bd7a9',
#   'embedding_type': 'commit_message',
#   'author': 'Vipin',
#   'repo': 'arunkenwal02/code-validator'},
#  {'created_at': '2025-08-05T04:26:18Z',
#   'author': 'Vipin',
#   'tag_id': 'push_metadata',
#   'file_name': 'No diff available',
#   'push_id': '52947410795',
#   'repo': 'arunkenwal02/code-validator',
#   'embedding_type': 'code_diff',
#   'commit_sha': '3235599a14b30870d1d26b5b3f3cb45796a4ba78'},
#  {'file_name': 'No diff available',
#   'created_at': '2025-08-05T04:26:18Z',
#   'commit_sha': '3235599a14b30870d1d26b5b3f3cb45796a4ba78',
#   'repo': 'arunkenwal02/code-validator',
#   'push_id': '52947410795',
#   'author': 'Vipin',
#   'embedding_type': 'commit_message',
#   'tag_id': 'push_metadata'},
#  {'created_at': '2025-08-04T08:46:35Z',
#   'author': 'Arun Kenwal',
#   'commit_sha': '9e8f1e36c0bdcc45ec0cb24122bfab05514e926b',
#   'push_id': '52905126625',
#   'tag_id': 'push_metadata',
#   'file_name': 'main.py',
#   'repo': 'arunkenwal02/code-validator',
#   'embedding_type': 'code_diff'},
#  {'push_id': '52905126625',
#   'repo': 'arunkenwal02/code-validator',
#   'file_name': 'main.py',
#   'commit_sha': '9e8f1e36c0bdcc45ec0cb24122bfab05514e926b',
#   'embedding_type': 'commit_message',
#   'created_at': '2025-08-04T08:46:35Z',
#   'tag_id': 'push_metadata',
#   'author': 'Arun Kenwal'},
#  {'tag_id': 'push_metadata',
#   'file_name': 'main.py',
#   'created_at': '2025-08-04T08:32:04Z',
#   'repo': 'arunkenwal02/code-validator',
#   'author': 'arunkenwal02',
#   'commit_sha': 'b8966abb082c689e1cbd27ff4f33cede1e8e945f',
#   'push_id': '52904484290',
#   'embedding_type': 'code_diff'},
#  {'tag_id': 'push_metadata',
#   'file_name': 'main.py',
#   'commit_sha': 'b8966abb082c689e1cbd27ff4f33cede1e8e945f',
#   'created_at': '2025-08-04T08:32:04Z',
#   'embedding_type': 'commit_message',
#   'repo': 'arunkenwal02/code-validator',
#   'push_id': '52904484290',
#   'author': 'arunkenwal02'},
#  {'push_id': '52901658358',
#   'repo': 'arunkenwal02/code-validator',
#   'file_name': 'main.ipynb',
#   'tag_id': 'push_metadata',
#   'commit_sha': '099c9ac21a023cc31580a485eb395dc88ab239dc',
#   'embedding_type': 'code_diff',
#   'author': 'Vipin',
#   'created_at': '2025-08-04T07:25:51Z'},
#  {'repo': 'arunkenwal02/code-validator',
#   'push_id': '52901658358',
#   'created_at': '2025-08-04T07:25:51Z',
#   'commit_sha': '099c9ac21a023cc31580a485eb395dc88ab239dc',
#   'author': 'Vipin',
#   'embedding_type': 'commit_message',
#   'file_name': 'main.ipynb',
#   'tag_id': 'push_metadata'},
#  {'push_id': '52821120274',
#   'file_name': 'main.ipynb',
#   'tag_id': 'push_metadata',
#   'commit_sha': '54097c86dc3bfadebb3ab591cd2cce4437e73dd1',
#   'created_at': '2025-08-01T07:33:25Z',
#   'repo': 'arunkenwal02/code-validator',
#   'author': 'Vipin',
#   'embedding_type': 'code_diff'},
#  {'author': 'Vipin',
#   'repo': 'arunkenwal02/code-validator',
#   'created_at': '2025-08-01T07:33:25Z',
#   'file_name': 'main.ipynb',
#   'push_id': '52821120274',
#   'commit_sha': '54097c86dc3bfadebb3ab591cd2cce4437e73dd1',
#   'tag_id': 'push_metadata',
#   'embedding_type': 'commit_message'}]

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage

llm = ChatOpenAI(model="gpt-4o", openai_api_key=openai_api_key)


def code_dif_summary(llm,collection ):

    results = collection.get(include=["documents", "metadatas"])

    # Extract only code diffs, using metadata
    code_diffs = [
        doc
        for doc, meta in zip(results["documents"], results["metadatas"])
        if meta.get("embedding_type") == "code_diff"
    ]

    code_diff_text = "\n\n".join(code_diffs)
    prompt = (
        "Summarize the following list of code diffs. Focus on major changes, added/removed functions, "
        "refactored code, or structural modifications. Use concise and clear language."
    )

    response = llm([
        SystemMessage(content=prompt),
        HumanMessage(content=code_diff_text)
    ])

    # print("Summary of code differences:\n")
    # print(response.content)

    return response.content

def comment_summary(llm,collection ):
    data = collection.get()
    summaries = []
    for meta in data['metadatas']:
        summary = (
            f"Commit by {meta.get('author', 'Unknown')} to repo '{meta.get('repo', '')}'\n"
            f"File changed: {meta.get('file_name', '')}\n"
            f"Push ID: {meta.get('push_id', '')}\n"
            f"Commit SHA: {meta.get('commit_sha', '')}\n"
            # f"Created at: {meta.get('created_at', '')}\n"
            # f"Type: {meta.get('embedding_type', '')}\n"
            f"Commit_message: {meta.get('commit_message', '')}\n"
            "------"
        )
        summaries.append(summary)

    summaries = "\n".join(summaries)

    # Prepare metadata as pretty strings (or dicts)
    meta_strings = summaries

    prompt = (
        '''
        You are an assistant. Summarize the following list of meta data commit message. 
        Summarizre the commit changes with commit sha,  file changes and keep both commit message  and commit summary eg. there are 4 commit output should be 4 pointer 
        and output structure:
        1. **Commit SHA:** c536e703bf0e78761d6374044ef7d9c2bb482131  
        **File Changed:** requirements.txt  
        **Commit Message:** Updated the requirements.txt
        **Commit Message Summary:** Updated the requirements.txt file.
        
        '''
    )

    response = llm([
        SystemMessage(content=prompt),
        HumanMessage(content="\n\n".join(meta_strings))
    ])

    # print(response.content)

    return response.content
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_11156\683693822.py:4: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(model="gpt-4o", openai_api_key=openai_api_key)

# %%
def comit_push_summary(llm,collection, file_path):
    code_dif_summ =code_dif_summary(llm,collection )
    comment_dif_summ = comment_summary(llm,collection )

    # Combine them into one text string
    combined_text = f"This is Push code summary differenc \n {code_dif_summ}\n\n Thsis is Commit summary b/w these pushes \n {comment_dif_summ}"


    print("Diff of Push Code summary:\n",code_dif_summ)
    print("+++++++++++++++++++++++++++++++++++++++++++++++++")
    print("Commit summary \n", comment_dif_summ )


    # Save to .txt file

    with open(file_path, "w", encoding="utf-8") as f:
        f.write(combined_text)

    print(f"Summary saved to {file_path}")

# %%
comit_push_summary(llm,collection, file_path)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_11156\683693822.py:24: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = llm([
# Diff of Push Code summary:
#  ### Major Changes:
#
# #### `requirements.txt`:
# - **Additions**: Added numerous new dependencies, such as `GitPython`, `Jinja2`, `Markdown`, `PyMuPDF`, `SQLAlchemy`, `FastAPI`, and several `langchain`-related packages.
# - **Removals**: Removed various dependencies including `appnope`, `argon2-cffi`, `arrow`, `bleach`, and many `jupyter`-related packages.
# - **Updates**: Some packages were updated to newer versions, such as `numpy` and `pandas`.
#
# #### `white paper.txt`:
# - **Removal**: Entire content related to feature implementation and validation metrics was removed.
#
# #### `main.py`:
# - **New Functions**:
#   - `refine_extracted_elements_with_context`: Refines extracted elements based on query context.
#   - `extract_from_pdf`: Extracts text from a PDF document.
#   - `create_chunks`, `create_embeddings`, `store_in_chromaDB`: Functions for chunking text, creating embeddings, and storing in a vector database.
#   - `summarize`: Summarizes findings from whitepaper and code.
#   - `queryFun`: Executes queries on a vector database and retrieves similar elements.
# - **Refactoring**:
#   - Enhanced the file processing logic to handle PDF extraction and embeddings.
#   - Integrated vector database interactions using `chromadb`.
#   - Adjusted comparison logic for functionalities between the whitepaper and code.
# - **Structural Modifications**: Introduced logic for handling both PDF and code files, leveraging embeddings and vector databases for analysis.
#
# #### `main.ipynb`:
# - **Addition**: Introduced a new Jupyter notebook file with code for reading notebooks, extracting functionalities, and comparing them with whitepaper requirements using LLM (Language Model).
#
# ### Overall:
# The main focus of these changes is on integrating PDF processing, vector embeddings, and database storage functionalities, significantly enhancing the capability to analyze and compare documents programmatically. The `requirements.txt` file updates reflect a shift towards using more advanced data processing and machine learning libraries.
# +++++++++++++++++++++++++++++++++++++++++++++++++
# Commit summary
#  1. **Commit SHA:** c536e703bf0e78761d6374044ef7d9c2bb482131
#    **File Changed:** requirements.txt
#    **Commit Message:**
#    **Commit Message Summary:** Updated the requirements.txt file.
#
# 2. **Commit SHA:** 5ef4b5b48eca8cad8d86e8d88904fcb2384e8dbb
#    **File Changed:** No diff available
#    **Commit Message:**
#    **Commit Message Summary:** No changes detected.
#
# 3. **Commit SHA:** 8ad9ffaa235a48de153eab057f7b819b7c1bd7a9
#    **File Changed:** whitepaper.txt
#    **Commit Message:**
#    **Commit Message Summary:** Updated the whitepaper.txt file.
#
# 4. **Commit SHA:** 9e8f1e36c0bdcc45ec0cb24122bfab05514e926b
#    **File Changed:** main.py
#    **Commit Message:**
#    **Commit Message Summary:** Updated the main.py file.
# Summary saved to Push_Commit_summary_outout.txt
